# %% [markdown]
# # 准备数据

# %%
# 加载模块
from datetime import datetime

from tqdm import tqdm
import rqdatac as rq

from vnpy.trader.database import DB_TZ
from vnpy.trader.datafeed import get_datafeed
from vnpy.trader.constant import Exchange, Interval
from vnpy.trader.object import HistoryRequest
from vnpy.alpha import AlphaLab, logger

# %%
# 设置下载参数
task_name = "csi300"
index_symbol = "000300.SSE"
rq_index_symbol = "000300.XSHG"

start_date = "2007-01-01"
end_date = "2024-10-31"

# %%
# 创建投研实验室
lab = AlphaLab(f"./lab/{task_name}")    # 指定数据文件夹

# %%
# 初始化数据服务（这里配置使用的RQData）
datafeed = get_datafeed()
datafeed.init()
# Out:
# True

# %%
# 下载指数成分股
data = rq.index_components(rq_index_symbol, start_date=start_date, end_date=end_date)

# 转换合约代码
index_components = {}
for dt, rq_symbols in data.items():
    vt_symbols: list = []

    for rq_symbol in rq_symbols:
        vt_symbol = rq_symbol.replace("XSHG", "SSE").replace("XSHE", "SZSE")
        vt_symbols.append(vt_symbol)

    index_components[dt.strftime("%Y-%m-%d")] = vt_symbols

# 保存到数据中心
lab.save_component_data(index_symbol, index_components)

# %%
# 加载指数成分股代码
component_symbols = lab.load_component_symbols(index_symbol, start_date, end_date)

# %%
# 转换时间格式
start = datetime.strptime(start_date, "%Y-%m-%d")
start = start.replace(tzinfo=DB_TZ)

end = datetime.strptime(end_date, "%Y-%m-%d")
end = end.replace(tzinfo=DB_TZ)

# 除了成分股，还要下载指数数据
task_symbols = component_symbols + [index_symbol]

# 遍历下载数据
for vt_symbol in tqdm(task_symbols):
    symbol, exchange_str = vt_symbol.split(".")

    req = HistoryRequest(symbol, Exchange(exchange_str), start, end, Interval.DAILY)
    bars = datafeed.query_bar_history(req)

    if bars:
        lab.save_bar_data(bars)
    else:
        logger.error(f"下载{vt_symbol}数据失败")
# Out:
#   0%|          | 0/859 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# QuotaExceeded                             Traceback (most recent call last)
# Cell In[11], line 16
#      13 symbol, exchange_str = vt_symbol.split(".")
#      15 req = HistoryRequest(symbol, Exchange(exchange_str), start, end, Interval.DAILY)
# ---> 16 bars = datafeed.query_bar_history(req)
#      18 if bars:
#      19     lab.save_bar_data(bars)
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/vnpy_rqdata/rqdata_datafeed.py:182, in RqdataDatafeed.query_bar_history(self, req, output)
#     180     return self._query_dominant_history(req, output)
#     181 else:
# --> 182     return self._query_bar_history(req, output)
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/vnpy_rqdata/rqdata_datafeed.py:227, in RqdataDatafeed._query_bar_history(self, req, output)
#     224 else:
#     225     adjust_type = "none"
# --> 227 df: DataFrame = get_price(
#     228     rq_symbol,
#     229     frequency=rq_interval,
#     230     fields=fields,
#     231     start_date=start,
#     232     end_date=get_next_trading_date(end),        # 为了查询夜盘数据
#     233     adjust_type=adjust_type
#     234 )
#     236 data: list[BarData] = []
#     238 if df is not None:
#     239     # 填充NaN为0
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/hk_decorators.py:142, in support_hk_order_book_id.<locals>.wrapped(*args, **kwargs)
#     140 # A fast call if user doesn't call for `hk` data.
#     141 if arguments.get("market", None) != "hk":
# --> 142     return f(*args, **kwargs)
#     144 reverse_map = {}
#     145 for k in ("order_book_id", "order_book_ids", "indexes"):
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/decorators.py:147, in compatible_with_parm.<locals>.wrap(*args, **kwargs)
#     145         if item != value:
#     146             raise ValueError("'{}': except '{}', got '{}'".format(name, value, item))
# --> 147 return func(*args, **kwargs)
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/services/get_price.py:93, in get_price(order_book_ids, start_date, end_date, frequency, fields, adjust_type, skip_suspended, expect_df, time_slice, market, **kwargs)
#      90         raise ValueError("time_slice: invalid, expect tuple or list value like ('09:55', '10:11'), got {}".format(time_slice))
#      91     start, end = to_time(time_slice[0]), to_time(time_slice[1])
# ---> 93 df = _get_price(
#      94     order_book_ids, start_date, end_date, frequency,
#      95     fields, adjust_type, skip_suspended, expect_df, market, **kwargs
#      96 )
#      98 if df is None or not sliceable or not time_slice:
#      99     # 非tick、minbar或者不指定切片时间，直接返回
#     100     return df
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/decorators.py:65, in retry.<locals>.decorate.<locals>.wrap(*args, **kwargs)
#      63 while c > 0:
#      64     try:
# ---> 65         return func(*args, **kwargs)
#      66     except suppress_exceptions as e:
#      67         c -= 1
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/services/get_price.py:164, in _get_price(order_book_ids, start_date, end_date, frequency, fields, adjust_type, skip_suspended, expect_df, market, **kwargs)
#     162 from rqdatac.services.detail.get_price_df import get_price_df, get_week_df
#     163 if frequency != 'w':
# --> 164     df = get_price_df(
#     165         order_book_ids, start_date, end_date, frequency, duration, fields, adjust_type, skip_suspended,
#     166         stocks, funds, indexes, futures, futures888, spots, options, convertibles, repos, market
#     167     )
#     168     if df is None or expect_df:
#     169         return df
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/services/detail/get_price_df.py:126, in get_price_df(order_book_ids, start_date, end_date, frequency, duration, fields, adjust_type, skip_suspended, stocks, funds, indexes, futures, futures888, spots, options, convertibles, repos, market)
#     106 def get_price_df(
#     107         order_book_ids,
#     108         start_date,
#    (...)
#     124         market
#     125 ):
# --> 126     live_date = current_trading_date()
#     127     if start_date > live_date:
#     128         return
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/decorators.py:126, in _ttl_cache_wrapper.<locals>.wrapper(*args, **kwargs)
#     124     if expire_at > time.time():
#     125         return value
# --> 126 value = user_function(*args, **kwargs)
#     127 cache[key] = (time.time() + ttl, value)
#     128 return value
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/services/calendar.py:197, in current_trading_date(market)
#     195 @ttl_cache(3)
#     196 def current_trading_date(market='cn'):
# --> 197     return get_client().execute('current_trading_date', market=market)
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/decorators.py:65, in retry.<locals>.decorate.<locals>.wrap(*args, **kwargs)
#      63 while c > 0:
#      64     try:
# ---> 65         return func(*args, **kwargs)
#      66     except suppress_exceptions as e:
#      67         c -= 1
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/rqdatac/connection_pool.py:27, in ConnectionPool.execute(self, method, *args, **kwargs)
#      25 with self._semaphore:
#      26     with self._get_connection() as conn:
# ---> 27         return conn.execute(method, *args, **kwargs)
#
# File rqdatac/connection.py:123, in rqdatac.connection.Connection.execute()
#
# File rqdatac/connection.py:93, in rqdatac.connection.Connection._read_one_packet()
#
# QuotaExceeded: Quota exceeded

# %%
# 添加回测参数配置
for vt_symbol in component_symbols:
    lab.add_contract_setting(
        vt_symbol,
        long_rate=5/10000,
        short_rate=10/10000,
        size=1,
        pricetick=0.0001,
    )
