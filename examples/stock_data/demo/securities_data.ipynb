# %%
import akshare as ak
df = ak.stock_info_a_code_name()
print(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 import akshare as ak
# ----> 2 df = ak.stock_info_a_code_name()
#       3 print(df)
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/akshare/stock/stock_info.py:456, in stock_info_a_code_name()
#     453 stock_kcb = stock_info_sh_name_code(symbol="科创板")
#     454 stock_kcb = stock_kcb[["证券代码", "证券简称"]]
# --> 456 stock_bse = stock_info_bj_name_code()
#     457 stock_bse = stock_bse[["证券代码", "证券简称"]]
#     458 stock_bse.columns = ["证券代码", "证券简称"]
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/akshare/stock/stock_info.py:207, in stock_info_bj_name_code()
#     205 big_df = pd.DataFrame()
#     206 tqdm = get_tqdm()
# --> 207 for page in tqdm(range(total_page), leave=False):
#     208     payload.update({"page": page})
# ...

# %%
import akshare as ak
import mplfinance as mpf  # Please install mplfinance as follows: pip install mplfinance

stock_us_daily_df = ak.stock_us_daily(symbol="AAPL", adjust="qfq")
stock_us_daily_df = stock_us_daily_df.set_index(["date"])
stock_us_daily_df = stock_us_daily_df["2020-04-01": "2020-04-29"]
mpf.plot(stock_us_daily_df, type="candle", mav=(3, 6, 9), volume=True, show_nontrading=False)

# %%
import akshare as ak

df = ak.stock_zh_a_tick_tx_js()
print(df)
# Out:
# /Users/sunshoucai/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/akshare/stock/stock_zh_a_tick_tx.py:27: UserWarning: 正在下载数据，请稍等
#   warnings.warn("正在下载数据，请稍等")
#           成交时间   成交价格  价格变动    成交量      成交金额  性质
# 0     09:25:00  11.44  0.00   7066   8083504  卖盘
# 1     09:30:00  11.44  0.00    783    895128  买盘
# 2     09:30:03  11.44  0.00   3044   3481277  买盘
# 3     09:30:06  11.42 -0.02   2476   2830101  卖盘
# 4     09:30:09  11.43  0.01    844    965095  买盘
# ...        ...    ...   ...    ...       ...  ..
# 4276  14:56:51  11.40  0.01    172    196028  买盘
# 4277  14:56:54  11.39 -0.01     68     77502  卖盘
# 4278  14:56:57  11.39  0.00     37     42143  卖盘
# 4279  14:57:00  11.39  0.00     19     21642  卖盘
# 4280  15:00:00  11.38 -0.01  10538  11991948  卖盘
#
# [4281 rows x 6 columns]

# %%
# Tushare（中国股市专用）：提供A股、港股的逐笔成交、订单簿数据，需注册获取Token
import tushare as ts
ts.set_token("5b03bbe59725c145f229d4eb7fe73d8fc9dc98d9cde5e194a0e4d708")
#sina数据
# df = ts.realtime_quote(ts_code='600000.SH,000001.SZ,000001.SH')
#东财数据
# df = ts.realtime_quote(ts_code='600000.SH', src='dc')
# print(df)

#sina数据
# df = ts.realtime_tick(ts_code='600000.SH')

pro = ts.pro_api()

# 获取所有正常上市的股票列表
df = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
print(df)

#东财数据
# df = ts.realtime_tick(ts_code='600000.SH', src='dc')
#
# print(df)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 16
#      13 pro = ts.pro_api()
#      15 # 获取所有正常上市的股票列表
# ---> 16 df = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
#      17 print(df)
#      19 #东财数据
#      20 # df = ts.realtime_tick(ts_code='600000.SH', src='dc')
#      21 #
#      22 # print(df)
#
# File ~/PycharmProjects/vnpy/.venv/lib/python3.10/site-packages/tushare/pro/client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您没有接口访问权限，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。

# %%
#东方财富获取数据
#https://datacenter-web.eastmoney.com/api/data/v1/get?reportName=RPT_IPO_ABSTOCK&columns=SECURITY_CODE,CHANGE_DATE,CHANGE_AFTER_FN,CHANGE_AFTER_AB,TRADE_MARKET_TYPE,RANK,SECUCODE&
